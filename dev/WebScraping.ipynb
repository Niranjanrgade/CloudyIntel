# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlsplit

# AWS documentation base URL and landing XML
BASE_URL = "https://docs.aws.amazon.com/"
LANDING_XML = "https://docs.aws.amazon.com/en_us/main-landing-page.xml"

# %%
# Define the 30–40 AWS core services you care about
CORE_SERVICES = {
    "lambda", "ec2", "s3", "iam", "rds", "dynamodb", "glue", "athena",
    "emr", "redshift", "sns", "sqs", "cloudformation", "cloudwatch",
    "kinesis", "ecs", "eks", "api-gateway", "sagemaker", "vpc",
    "route53", "cloudtrail", "kms", "ssm", "secrets-manager", "opensearch",
    "elasticsearch", "athena", "lakeformation", "batch", "elasticbeanstalk",
    "transfer", "backup", "cloudfront", "appsync", "step-functions"
}

# %%
def fetch(url):
    """Download and return text content from a URL."""
    r = requests.get(url, timeout=30)
    r.raise_for_status()
    return r.text

# %%
xml = fetch(LANDING_XML)

# %%
xml
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<main-landing-page version="2.1">\n   <title>Welcome to AWS Documentation</title>\n   <abstract>Find user guides, code samples, SDKs &amp; toolkits, tutorials, API &amp; CLI references, and more.</abstract>\n   <feedbackCTI>Landing Pages</feedbackCTI>\n   <sections>\n      <section id="welcome">\n         <cards>\n            <list-card id="featured-content">\n               <title>Featured content</title>\n               <list-card-items>\n                  <list-card-item href="/ec2/?icmpid=docs_homepage_featuredsvcs" id="ec2">\n                     <title>\n                                Amazon EC2\n                            </title>\n                     <abstract>Create and run virtual servers in the cloud</abstract>\n                     <image src="images/service-icons/Arch_Amazon-EC2_32.svg">\n                        <alt>Amazon EC2 icon</alt>\n                     \n                  </list-card-item>\n                  <list-card-item href="/s3/?icmpid=docs_homepage_featuredsvcs" id="S3">\n                     <title>\n                                Amazon S3\n                            </title>\n                     <abstract>Object storage built to retrieve any amount of data from anywhere</abstract>\n                     <image src="images/service-icons/Arch_Amazon-Simple-Storage-Service_32.svg">\n                        <alt>Amazon S3 icon</alt>\n                     \n                  </list-card-item>\n                  <list-card-item href="/dynamodb/?icmpid=docs_homepage_featuredsvcs" id="dynamodb">\n                     <title>\n                                Amazon DynamoDB\n                            </title>\n                     <abstract>Managed NoSQL database service</abstract>\n                     <image src="images/service-icons/Arch_Amazon-DynamoDB_32.svg">\n                        <alt>Amazon DynamoDB icon</alt>\n                     \n                  </list-card-item>\n                  <list-card-item href="/rds/?icmpid=docs_homepage_featuredsvcs" id="rds">\n                     <title>\n                                Amazon Relational Database Service\n                            </title>\n                     <abstract>Set up, operate, and scale a relational database in the cloud</abstract>\n                     <image src="images/service-icons/Arch_Amazon-RDS_32.svg">\n                        <alt>Amazon RDS icon</alt>\n                     \n                  </list-card-item>\n                  <list-card-item href="/lambda/?icmpid=docs_homepage_featuredsvcs" id="lambda">\n                     <title>\n                                AWS Lambda\n                            </title>\n                     <abstract>Run code without thinking about servers</abstract>\n                     <image src="images/service-icons/Arch_AWS-Lambda_32.svg">\n                        <alt>AWS Lambda icon</alt>\n                     \n                  </list-card-item>\n                  <list-card-item href="/vpc/?icmpid=docs_homepage_featuredsvcs" id="VPC">\n                     <title>\n                                Amazon VPC\n                            </title>\n                     <abstract>Isolated cloud resources</abstract>\n                     <image src="images/service-icons/Arch_Amazon-Virtual-Private-Cloud_32.svg">\n                        <alt>Amazon VPC icon</alt>\n                     \n                  </list-card-item>\n                  <list-card-item href="/next-generation-sagemaker/latest/userguide?icmpid=docs_homepage_featuredsvcs"\n                                  id="SageMakerPlain">\n                     <title>\n                                Amazon SageMaker\n                            </title>\n                     <abstract>The center for all data, analytics, and AI</abstract>\n                     <image src="images/service-icons/Arch_Amazon-SageMaker_32.svg">\n                        <alt>Amazon SageMaker icon</alt>\n ...

# %%
soup = BeautifulSoup(xml, "xml")

# %%
soup
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <main-landing-page version="2.1">
# <title>Welcome to AWS Documentation</title>
# <abstract>Find user guides, code samples, SDKs &amp; toolkits, tutorials, API &amp; CLI references, and more.</abstract>
# <feedbackCTI>Landing Pages</feedbackCTI>
# <sections>
# <section id="welcome">
# <cards>
# <list-card id="featured-content">
# <title>Featured content</title>
# <list-card-items>
# <list-card-item href="/ec2/?icmpid=docs_homepage_featuredsvcs" id="ec2">
# <title>
#                                 Amazon EC2
#                             </title>
# <abstract>Create and run virtual servers in the cloud</abstract>
# <image src="images/service-icons/Arch_Amazon-EC2_32.svg">
# <alt>Amazon EC2 icon</alt>
#
# </list-card-item>
# <list-card-item href="/s3/?icmpid=docs_homepage_featuredsvcs" id="S3">
# <title>
#                                 Amazon S3
#                             </title>
# <abstract>Object storage built to retrieve any amount of data from anywhere</abstract>
# <image src="images/service-icons/Arch_Amazon-Simple-Storage-Service_32.svg">
# <alt>Amazon S3 icon</alt>
#
# </list-card-item>
# <list-card-item href="/dynamodb/?icmpid=docs_homepage_featuredsvcs" id="dynamodb">
# <title>
#                                 Amazon DynamoDB
#                             </title>
# <abstract>Managed NoSQL database service</abstract>
# <image src="images/service-icons/Arch_Amazon-DynamoDB_32.svg">
# <alt>Amazon DynamoDB icon</alt>
#
# </list-card-item>
# <list-card-item href="/rds/?icmpid=docs_homepage_featuredsvcs" id="rds">
# <title>
#                                 Amazon Relational Database Service
#                             </title>
# <abstract>Set up, operate, and scale a relational database in the cloud</abstract>
# <image src="images/service-icons/Arch_Amazon-RDS_32.svg">
# <alt>Amazon RDS icon</alt>
#
# </list-card-item>
# <list-card-item href="/lambda/?icmpid=docs_homepage_featuredsvcs" id="lambda">
# <title>
#                                 AWS Lambda
#                             </title>
# <abstract>Run code without thinking about servers</abstract>
# <image src="images/service-icons/Arch_AWS-Lambda_32.svg">
# <alt>AWS Lambda icon</alt>
#
# </list-card-item>
# <list-card-item href="/vpc/?icmpid=docs_homepage_featuredsvcs" id="VPC">
# <title>
#                                 Amazon VPC
#                             </title>
# <abstract>Isolated cloud resources</abstract>
# <image src="images/service-icons/Arch_Amazon-Virtual-Private-Cloud_32.svg">
# <alt>Amazon VPC icon</alt>
#
# </list-card-item>
# <list-card-item href="/next-generation-sagemaker/latest/userguide?icmpid=docs_homepage_featuredsvcs" id="SageMakerPlain">
# <title>
#                                 Amazon SageMaker
#                             </title>
# <abstract>The center for all data, analytics, and AI</abstract>
# <image src="images/service-icons/Arch_Amazon-SageMaker_32.svg">
# <alt>Amazon SageMaker icon</alt>
#
# </list-card-item>
# <list-card-item href="/decision-guides/latest/generative-ai-on-aws-how-to-choose/guide.html?icmpid=docs_homepage_featuredsvcs">
# <title>Choosing a generative AI service</title>
# <abstract>Determine which AWS generative AI services are the best fit for your organization</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Decision guide icon</alt>
#
# </list-card-item>
# <list-card-item href="/decision-guides/latest/bedrock-or-sagemaker/bedrock-or-sagemaker.html?icmpid=docs_homepage_featuredsvcs">
# <title>Amazon Bedrock or Amazon SageMaker AI?</title>
# <abstract>Determine which service is the best fit for your needs</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Decision guide icon</alt>
#
# </list-card-item>
# </list-card-items>
# </list-card>
# <simple-card>
# <title>Getting started with AWS</title>
# <abstract>Learn the fundamentals and start building on AWS. Find best practices to help you launch your first application and get to know the AWS Management Console.</abstract>
# <footer>
# <footer-item href="https://aws.amazon.com/getting-started/guides/setup-environment/">Set up your AWS environment</footer-item>
# <footer-item href="https://aws.amazon.com/getting-started/?ref=docs_gateway">Getting Started Resource Center</footer-item>
# <footer-item href="https://aws.amazon.com/security/">AWS Cloud Security</footer-item>
# </footer>
# </simple-card>
# <image-card>
# <title href="https://aws.amazon.com/getting-started/hands-on/">Hands-on Tutorials</title>
# <abstract>Get started with step-by-step tutorials to launch your first application</abstract>
# <image src="images/cards/hands-on-tutorials-light.svg" src-dark="images/cards/hands-on-tutorials-dark.svg">
# <alt>Hands-on tutorials icon</alt>
#
# <footer/>
# </image-card>
# <image-card>
# <title href="https://aws.amazon.com/prescriptive-guidance">AWS Prescriptive Guidance</title>
# <abstract>Resources to help you accelerate cloud adoption and modernization</abstract>
# <image src="images/cards/aws-prescriptive-guidance-light.svg" src-dark="images/cards/aws-prescriptive-guidance-dark.svg">
# <alt>AWS Prescriptive Guidance icon</alt>
#
# <footer/>
# </image-card>
# <image-card>
# <title href="https://aws.amazon.com/architecture/">AWS Architecture Center</title>
# <abstract>Learn how to architect more effectively on AWS</abstract>
# <image src="images/cards/aws-arch-center-light.svg" src-dark="images/cards/aws-arch-center-dark.svg">
# <alt>AWS Architecture Center icon</alt>
#
# <footer/>
# </image-card>
# <image-card>
# <title href="https://aws.amazon.com/solutions/">AWS Solutions Library</title>
# <abstract>Find vetted solutions and guidance for business and technical use cases</abstract>
# <image src="images/cards/aws-solutions-library-light.svg" src-dark="images/cards/aws-solutions-library-dark.svg">
# <alt>AWS Solutions Library icon</alt>
#
# <footer/>
# </image-card>
# </cards>
# </section>
# <section id="products">
# <title>Product guides &amp; references</title>
# <subtitle>Find user guides, developer guides, API references, and CLI references for
#                 your AWS products.</subtitle>
# <cards>
# <list-card id="DocsCategory-analytics">
# <title>Analytics</title>
# <list-card-items>
# <list-card-item href="/decision-guides/latest/analytics-on-aws-how-to-choose/analytics-on-aws-how-to-choose.html?icmpid=docs_homepage_analytics">
# <title>Choosing an AWS analytics service</title>
# <abstract>Ask the right questions to build your modern data architecture on AWS services</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Decision guide icon</alt>
#
# </list-card-item>
# <list-card-item href="/next-generation-sagemaker/latest/userguide?icmpid=docs_homepage_analytics" id="SageMakerPlain">
# <title>
#                                 Amazon SageMaker
#                             </title>
# <abstract>The center for all data, analytics, and AI</abstract>
# </list-card-item>
# <list-card-item href="/appflow/?icmpid=docs_homepage_analytics" id="apfl">
# <title>
#                                 Amazon AppFlow
#                             </title>
# <abstract>No-code integration for SaaS apps and AWS services</abstract>
# <image src="images/service-icons/Arch_Amazon-AppFlow_32.svg">
# <alt>Amazon AppFlow icon</alt>
#
# </list-card-item>
# <list-card-item href="/athena/?icmpid=docs_homepage_analytics" id="athena">
# <title>
#                                 Amazon Athena
#                             </title>
# <abstract>Query data in Amazon S3 using SQL</abstract>
# <image src="images/service-icons/Arch_Amazon-Athena_32.svg">
# <alt>Amazon Athena icon</alt>
#
# </list-card-item>
# <list-card-item href="/clean-rooms/?icmpid=docs_homepage_analytics" id="cleanrooms">
# <title>
#                                 AWS Clean Rooms
#                             </title>
# <abstract>Collaborate and analyze collective datasets without sharing raw data</abstract>
# <image src="images/service-icons/Arch_AWS-Clean-Rooms_32.svg">
# <alt>AWS Clean Rooms icon</alt>
#
# </list-card-item>
# <list-card-item href="/cloudsearch/?icmpid=docs_homepage_analytics" id="cloudsearch">
# <title>
#                                 Amazon CloudSearch
#                             </title>
# <abstract>Managed search service</abstract>
# <image src="images/service-icons/Arch_Amazon-CloudSearch_32.svg">
# <alt>Amazon CloudSearch icon</alt>
#
# </list-card-item>
# <list-card-item href="/data-exchange/?icmpid=docs_homepage_analytics" id="dataexchange">
# <title>
#                                 AWS Data Exchange
#                             </title>
# <abstract>Find, subscribe to, and use third-party data in the cloud</abstract>
# <image src="images/service-icons/Arch_AWS-Data-Exchange_32.svg">
# <alt>AWS Data Exchange icon</alt>
#
# </list-card-item>
# <list-card-item href="/firehose/?icmpid=docs_homepage_analytics" id="kinesisfirehose" validate="true">
# <title>
#                                 Amazon Data Firehose
#                             </title>
# <abstract>Fully managed real-time streaming data delivery service</abstract>
# <image src="images/service-icons/Arch_AWS-Data-Exchange_32.svg">
# <alt>Amazon Data Firehose icon</alt>
#
# </list-card-item>
# <list-card-item href="/data-pipeline/?icmpid=docs_homepage_analytics" id="datapipeline">
# <title>
#                                 AWS Data Pipeline
#                             </title>
# <abstract>Orchestration service for periodic, data-driven workflows</abstract>
# <image src="images/service-icons/Arch_AWS-Data-Pipeline_32.svg">
# <alt>AWS Data Pipeline icon</alt>
#
# </list-card-item>
# <list-card-item href="/datazone/?icmpid=docs_homepage_analytics" id="datazone">
# <title>
#                                 Amazon DataZone
#                             </title>
# <abstract>Unlock data across organizational boundaries with built-in governance</abstract>
# <image src="images/service-icons/Arch-Category_Analytics_32.svg">
# <alt>Amazon DataZone icon</alt>
#
# </list-card-item>
# <list-card-item href="/emr/?icmpid=docs_homepage_analytics" id="emr">
# <title>
#                                 Amazon EMR
#                             </title>
# <abstract>Hosted Hadoop framework</abstract>
# <image src="images/service-icons/Arch_Amazon-EMR_32.svg">
# <alt>Amazon EMR icon</alt>
#
# </list-card-item>
# <list-card-item href="/entityresolution/?icmpid=docs_homepage_analytics" id="entityresolution">
# <title>
#                                 AWS Entity Resolution
#                             </title>
# <abstract>Link records stored across multiple applications, channels, and data stores</abstract>
# <image src="images/service-icons/Arch-Category_Analytics_32.svg">
# <alt>AWS Entity Resolution icon</alt>
#
# </list-card-item>
# <list-card-item href="/finspace/?icmpid=docs_homepage_analytics" id="finspace">
# <title>
#                                 Amazon FinSpace
#                             </title>
# <abstract>Store, catalog, prepare, and analyze financial industry data</abstract>
# <image src="images/service-icons/Arch_Amazon-FinSpace_32.svg">
# <alt>Amazon FinSpace icon</alt>
#
# </list-card-item>
# <list-card-item href="/glue/?icmpid=docs_homepage_analytics" id="glue">
# <title>
#                                 AWS Glue
#                             </title>
# <abstract>Simple, scalable, and serverless data integration</abstract>
# <image src="images/service-icons/Arch_AWS-Glue_32.svg">
# <alt>AWS Glue icon</alt>
#
# </list-card-item>
# <list-card-item href="/kinesis/?icmpid=docs_homepage_analytics" id="AK">
# <title>
#                                 Amazon Kinesis
#                             </title>
# <abstract>Analyze real-time video and data streams</abstract>
# <image src="images/service-icons/Arch_Amazon-Kinesis_32.svg">
# <alt>Amazon Kinesis icon</alt>
#
# </list-card-item>
# <list-card-item href="/lake-formation/?icmpid=docs_homepage_analytics" id="lakeformation">
# <title>
#                                 AWS Lake Formation
#                             </title>
# <abstract>Build a secure data lake in days</abstract>
# <image src="images/service-icons/Arch_AWS-Lake-Formation_32.svg">
# <alt>AWS Lake Formation icon</alt>
#
# </list-card-item>
# <list-card-item href="/managed-flink/?icmpid=docs_homepage_analytics" id="kinesisanalytics" validate="true">
# <title>
#                                 Amazon Managed Service for Apache Flink
#                             </title>
# <abstract>Process and analyze streaming data using Apache Flink</abstract>
# <image src="images/service-icons/Arch_Amazon-Kinesis_32.svg">
# <alt>Amazon Managed Service for Apache Flink icon</alt>
#
# </list-card-item>
# <list-card-item href="/msk/?icmpid=docs_homepage_analytics" id="msk">
# <title>
#                                 Amazon MSK
#                             </title>
# <abstract>Fully managed Apache Kafka service</abstract>
# <image src="images/service-icons/Arch_Amazon-Managed-Streaming-for-Apache-Kafka_32.svg">
# <alt>Amazon MSK icon</alt>
#
# </list-card-item>
# <list-card-item href="/opensearch-service/?icmpid=docs_homepage_analytics" id="elasticsearchservice">
# <title>
#                                 Amazon OpenSearch Service
#                             </title>
# <abstract>Deploy, operate, and scale OpenSearch clusters in the AWS Cloud</abstract>
# <image src="images/service-icons/Arch_Amazon-OpenSearch-Service_32.svg">
# <alt>Amazon OpenSearch Service icon</alt>
#
# </list-card-item>
# <list-card-item href="/quicksuite/?icmpid=docs_homepage_analytics" id="quicksight">
# <title>
#                                 Amazon Quick Suite
#                             </title>
# <abstract>Fast business analytics service</abstract>
# <image src="images/service-icons/Arch_Amazon-QuickSight_32.svg">
# <alt>Amazon Quick Suite icon</alt>
#
# </list-card-item>
# <list-card-item href="/redshift/?icmpid=docs_homepage_analytics" id="redshift">
# <title>
#                                 Amazon Redshift
#                             </title>
# <abstract>Fast, simple, cost-effective data warehouse service</abstract>
# <image src="images/service-icons/Arch_Amazon-Redshift_32.svg">
# <alt>Amazon Redshift icon</alt>
#
# </list-card-item>
# </list-card-items>
# </list-card>
# <list-card id="DocsCategory-applicationintegration">
# <title>Application Integration</title>
# <list-card-items>
# <list-card-item href="/b2bi/?icmpid=docs_homepage_appintegration" id="b2bi" validate="true">
# <title>
#                                 AWS B2B Data Interchange
#                             </title>
# <abstract>Enables automated exchange of EDI-based transactions</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>AWS B2B Data Interchange icon</alt>
#
# </list-card-item>
# <list-card-item href="/decision-guides/latest/application-integration-on-aws-how-to-choose/application-integration-on-aws-how-to-choose.html?icmpid=docs_homepage_appintegration">
# <title>Choosing an AWS application integration service</title>
# <abstract>Choose an AWS application integration service for your workloads</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Decision guide icon</alt>
#
# </list-card-item>
# <list-card-item href="/eventbridge/?icmpid=docs_homepage_appintegration" id="eventbridge">
# <title>
#                                 Amazon EventBridge
#                             </title>
# <abstract>Serverless event bus for SaaS apps and AWS services</abstract>
# <image src="images/service-icons/Arch_Amazon-EventBridge_32.svg">
# <alt>Amazon EventBridge icon</alt>
#
# </list-card-item>
# <list-card-item href="/amazon-mq/?icmpid=docs_homepage_appintegration" id="amazonmq">
# <title>
#                                 Amazon MQ
#                             </title>
# <abstract>Managed message broker service</abstract>
# <image src="images/service-icons/Arch_Amazon-MQ_32.svg">
# <alt>Amazon MQ icon</alt>
#
# </list-card-item>
# <list-card-item href="/mwaa/?icmpid=docs_homepage_appintegration" id="airflow">
# <title>
#                                 Amazon MWAA
#                             </title>
# <abstract>Managed orchestration service for Apache Airflow</abstract>
# <image src="images/service-icons/Arch_Amazon-Managed-Workflows-for-Apache-Airflow_32.svg">
# <alt>Amazon Managed Workflows for Apache Airflow icon</alt>
#
# </list-card-item>
# <list-card-item href="/sns/?icmpid=docs_homepage_appintegration" id="sns">
# <title>
#                                 Amazon SNS
#                             </title>
# <abstract>Pub/sub, SMS, email, and mobile push notifications</abstract>
# <image src="images/service-icons/Arch_Amazon-Simple-Notification-Service_32.svg">
# <alt>Amazon SNS icon</alt>
#
# </list-card-item>
# <list-card-item href="/sqs/?icmpid=docs_homepage_appintegration" id="sqs">
# <title>
#                                 Amazon SQS
#                             </title>
# <abstract>Managed message queues</abstract>
# <image src="images/service-icons/Arch_Amazon-Simple-Queue-Service_32.svg">
# <alt>Amazon SQS icon</alt>
#
# </list-card-item>
# <list-card-item href="/step-functions/?icmpid=docs_homepage_appintegration" id="states">
# <title>
#                                 AWS Step Functions
#                             </title>
# <abstract>Coordination for distributed applications</abstract>
# <image src="images/service-icons/Arch_AWS-Step-Functions_32.svg">
# <alt>AWS Step Functions icon</alt>
#
# </list-card-item>
# <list-card-item href="/swf/?icmpid=docs_homepage_appintegration" id="swf">
# <title>
#                                 Amazon SWF
#                             </title>
# <abstract>Build applications that coordinate work across distributed components</abstract>
# <image src="images/service-icons/Arch-Category_Application-Integration_32.svg">
# <alt>Amazon SWF icon</alt>
#
# </list-card-item>
# </list-card-items>
# </list-card>
# <list-card id="DocsCategory-awsmanagementconsole">
# <title>
#                         AWS Management Console
#                     </title>
# <list-card-items>
# <list-card-item href="/consolemobileapp/?icmpid=docs_homepage_console" id="CMA">
# <title>
#                                 AWS Console Mobile Application
#                             </title>
# <abstract>View and manage resources to support incident response while on the go</abstract>
# <image src="images/service-icons/Arch_AWS-Console-Mobile-Application _32.svg">
# <alt>AWS Console Mobile Application icon</alt>
#
# </list-card-item>
# <list-card-item href="/awsconsolehelpdocs/latest/gsg/getting-started.html?icmpid=docs_homepage_console" id="awsmanagementconsole">
# <title>
#                                 AWS Management Console
#                             </title>
# <abstract>Web-based user interface comprising multiple AWS service consoles</abstract>
# <image src="images/service-icons/Arch_AWS-Management-Console_32.svg">
# <alt>AWS Management Console icon</alt>
#
# </list-card-item>
# <list-card-item href="/amazonq/?icmpid=docs_homepage_console">
# <title>Amazon Q</title>
# <abstract>Generative AI-powered assistants</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Amazon Q icon</alt>
#
# </list-card-item>
# <list-card-item href="/signin/latest/userguide/what-is-sign-in.html?icmpid=docs_homepage_console">
# <title>
#                                 AWS Sign-In
#                             </title>
# <abstract>Find help signing in and out of your account</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>AWS Sign-In icon</alt>
#
# </list-card-item>
# </list-card-items>
# </list-card>
# <list-card id="DocsCategory-blockchain">
# <title>Blockchain</title>
# <list-card-items>
# <list-card-item href="/blockchain-templates/?icmpid=docs_homepage_blockchain">
# <title>
#                                 AWS
#                                 Blockchain Templates
#                             </title>
# <abstract>Quickly create and deploy open-source blockchain frameworks on AWS</abstract>
# <image src="images/service-icons/Arch-Category_Blockchain_32.svg">
# <alt>AWSBlockchain Templates icon</alt>
#
# </list-card-item>
# <list-card-item href="/managed-blockchain/?icmpid=docs_homepage_blockchain" id="AMB">
# <title>
#                                 Amazon Managed Blockchain
#                             </title>
# <abstract>Create and manage scalable blockchain networks</abstract>
# <image src="images/service-icons/Arch_Amazon-Managed-Blockchain_32.svg">
# <alt>Amazon Managed Blockchain icon</alt>
#
# </list-card-item>
# </list-card-items>
# </list-card>
# <list-card id="DocsCategory-businessapplications">
# <title>Business Applications</title>
# <list-card-items>
# <list-card-item href="/appfabric/?icmpid=docs_homepage_busapp" id="aws-fabric">
# <title>
#                                 AWS AppFabric
#                             </title>
# <abstract>Aggregate and analyze data across SaaS applications</abstract>
# <image src="images/service-icons/Arch-Category_Business-Applications_32.svg">
# <alt>AWS AppFabric icon</alt>
#
# </list-card-item>
# <list-card-item href="/appstudio/?icmpid=docs_homepage_busapp">
# <title>
#                                 AWS
#                                 App Studio
#                             </title>
# <abstract>Build internal applications to automate processes and simplify organization
#                                 activities</abstract>
# <image src="images/service-icons/Arch-Category_Business-Applications_32.svg">
# <alt>AWSApp Studio icon</alt>
#
# </list-card-item>
# <list-card-item href="/chime/?icmpid=docs_homepage_busapp" id="chime">
# <title>
#                                 Amazon Chime
#                             </title>
# <abstract>Frustration-free meetings, video calls, and chat</abstract>
# <image src="images/service-icons/Arch_Amazon-Chime_32.svg">
# <alt>Amazon Chime icon</alt>
#
# </list-card-item>
# <list-card-item href="/chime-sdk/?icmpid=docs_homepage_busapp" id="chime-sdk">
# <title>Amazon Chime SDK</title>
# <abstract>Real-time messaging, audio, video, and screen sharing</abstract>
# <image src="images/service-icons/Arch_Amazon-Chime-SDK_32.svg">
# <alt>Amazon Chime SDK icon</alt>
#
# </list-card-item>
# <list-card-item href="/connect/?icmpid=docs_homepage_busapp" id="lily">
# <title>
#                                 Amazon Connect
#                             </title>
# <abstract>Omnichannel cloud contact center</abstract>
# <image src="images/service-icons/Arch_Amazon-Connect_32.svg">
# <alt>Amazon Connect icon</alt>
#
# </list-card-item>
# <list-card-item href="/end-user-messaging/?icmpid=docs_homepage_busapp">
# <title>
#                                 AWS
#                                 End User Messaging Push
#                             </title>
# <abstract>Application-to-person push notification service</abstract>
# <image src="images/service-icons/Arch-Category_Business-Applications_32.svg">
# <alt>AWSApp Studio icon</alt>
#
# </list-card-item>
# <list-card-item href="/sms-voice/?icmpid=docs_homepage_busapp" id="pinpoint-sms-voice-v2">
# <title>
#                                 AWS End User Messaging SMS
#                             </title>
# <abstract>Application-to-person SMS messaging service</abstract>
# <image src="images/service-icons/Arch_Amazon-Pinpoint_32.svg">
# <alt>AWS End User Messaging SMS icon</alt>
#
# </list-card-item>
# <list-card-item href="/end-user-messaging/?icmpid=docs_homepage_busapp" id="social-messaging">
# <title>
#                                 AWS End User Messaging Social
#                             </title>
# <abstract>Application-to-person WhatsApp messaging service</abstract>
# <image src="images/service-icons/Arch_Amazon-Simple-Email-Service_32.svg">
# <alt>
#                                     AWS End User Messaging Social
#                                 </alt>
#
# </list-card-item>
# <list-card-item href="/one-enterprise/latest/userguide?icmpid=docs_homepage_busapp">
# <title>Amazon One Enterprise</title>
# <abstract>Palm-based authentication for secure building access</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Amazon One Enterprise icon</alt>
#
# </list-card-item>
# <list-card-item href="/pinpoint/?icmpid=docs_homepage_busapp" id="pinpoint">
# <title>
#                                 Amazon Pinpoint
#                             </title>
# <abstract>Multichannel marketing communications</abstract>
# <image src="images/service-icons/Arch_Amazon-Pinpoint_32.svg">
# <alt>Amazon Pinpoint icon</alt>
#
# </list-card-item>
# <list-card-item href="/ses/?icmpid=docs_homepage_busapp" id="ses">
# <title>
#                                 Amazon Simple Email Service
#                             </title>
# <abstract>High-scale inbound and outbound email</abstract>
# <image src="images/service-icons/Arch_Amazon-Simple-Email-Service_32.svg">
# <alt>Amazon SES icon</alt>
#
# </list-card-item>
# <list-card-item href="/aws-supply-chain/?icmpid=docs_homepage_busapp" id="ip-scdv">
# <title>
#                                 AWS Supply Chain
#                             </title>
# <abstract>Reduce risks and lower costs with ML-powered supply chain application</abstract>
# <image src="images/service-icons/Arch_AWS-Supply-Chain_32.svg">
# <alt>AWS Supply Chain icon</alt>
#
# </list-card-item>
# <list-card-item href="/wickr/?icmpid=docs_homepage_busapp" id="wickr">
# <title>
#                                 AWS Wickr
#                             </title>
# <abstract>Protect enterprise communications with end-to-end encryption</abstract>
# <image src="images/service-icons/Arch_AWS-Wickr_32.svg">
# <alt>AWS Wickr icon</alt>
#
# </list-card-item>
# <list-card-item href="/workmail/?icmpid=docs_homepage_busapp" id="workmail">
# <title>
#                                 Amazon WorkMail
#                             </title>
# <abstract>Secure email and calendaring</abstract>
# <image src="images/service-icons/Arch_Amazon-WorkMail_32.svg">
# <alt>Amazon WorkMail icon</alt>
#
# </list-card-item>
# </list-card-items>
# </list-card>
# <list-card id="DocsCategory-cloudfinancialmanagement">
# <title>Cloud Financial Management</title>
# <list-card-items>
# <list-card-item href="/decision-guides/latest/cost-management-on-aws-how-to-choose/cost-management-on-aws-how-to-choose.html?icmpid=docs_homepage_cloudfin">
# <title>Choosing an AWS cost management strategy</title>
# <abstract>Ask the right questions to determine which cost management services fit your needs</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Decision guide icon</alt>
#
# </list-card-item>
# <list-card-item href="/account-billing/?icmpid=docs_homepage_cloudfin" id="awsbillingconsole">
# <title>
#                                 AWS Billing and Cost Management
#                             </title>
# <abstract>Find features that help you pay your bills and optimize your costs</abstract>
# <image src="images/service-icons/Arch-Category_Cloud-Financial-Management_32.svg">
# <alt>AWS Billing and Cost Management icon</alt>
#
# </list-card-item>
# <list-card-item href="/pricing-calculator/?icmpid=docs_homepage_cloudfin" id="APC">
# <title>
#                                 AWS Pricing Calculator
#                             </title>
# <abstract>Create cost estimates that match your AWS use case</abstract>
# <image src="images/service-icons/Arch-Category_Cloud-Financial-Management_32.svg">
# <alt>AWS Pricing Calculator icon</alt>
#
# </list-card-item>
# <list-card-item href="/savingsplans/?icmpid=docs_homepage_cloudfin" id="savings-plans">
# <title>
#                                 Savings Plans
#                             </title>
# <abstract>Save on compute usage with flexible pricing</abstract>
# <image src="images/service-icons/Arch_Savings-Plans_32.svg">
# <alt>Savings Plans icon</alt>
#
# </list-card-item>
# </list-card-items>
# </list-card>
# <list-card id="DocsCategory-compute">
# <title>Compute</title>
# <list-card-items>
# <list-card-item href="/decision-guides/latest/compute-on-aws-how-to-choose/choosing-aws-compute-service.html?icmpid=docs_homepage_compute">
# <title>Choosing an AWS compute service</title>
# <abstract>Choose the right AWS compute services for your workloads</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Decision guide icon</alt>
#
# </list-card-item>
# <list-card-item href="/apprunner/?icmpid=docs_homepage_compute" id="apprunner">
# <title>
#                                 AWS App Runner
#                             </title>
# <abstract>Production web applications at scale made easy for developers</abstract>
# <image src="images/service-icons/Arch_AWS-App-Runner_32.svg">
# <alt>AWS App Runner icon</alt>
#
# </list-card-item>
# <list-card-item href="/ec2/?icmpid=docs_homepage_compute" id="ec2">
# <title>
#                                 Amazon EC2
#                             </title>
# <abstract>Create and run virtual servers in the cloud with Amazon EC2</abstract>
# <image src="images/service-icons/Arch_Amazon-EC2_32.svg">
# <alt>Amazon EC2 icon</alt>
#
# </list-card-item>
# <list-card-item href="/elastic-beanstalk/?icmpid=docs_homepage_compute" id="elasticbeanstalk">
# <title>
#                                 AWS Elastic Beanstalk
#                             </title>
# <abstract>Run and manage web apps</abstract>
# <image src="images/service-icons/Arch_AWS-Elastic-Beanstalk_32.svg">
# <alt>AWS Elastic Beanstalk icon</alt>
#
# </list-card-item>
# <list-card-item href="/lambda/?icmpid=docs_homepage_compute" id="lambda">
# <title>
#                                 AWS Lambda
#                             </title>
# <abstract>Run code without thinking about servers</abstract>
# <image src="images/service-icons/Arch_AWS-Lambda_32.svg">
# <alt>AWS Lambda icon</alt>
#
# </list-card-item>
# <list-card-item href="/lightsail/?icmpid=docs_homepage_compute" id="lightsail">
# <title>
#                                 Amazon Lightsail
#                             </title>
# <abstract>Launch and manage virtual private servers</abstract>
# <image src="images/service-icons/Arch_Amazon-Lightsail_32.svg">
# <alt>Amazon Lightsail icon</alt>
#
# </list-card-item>
# <list-card-item href="/linux/?icmpid=docs_homepage_compute">
# <title>
#                                 Amazon Linux
#                             </title>
# <abstract>Portfolio of modern Linux-based high performance operating systems</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Amazon Linux icon</alt>
#
# </list-card-item>
# <list-card-item href="/local-zones/?icmpid=docs_homepage_compute">
# <title>
#                                 AWS
#                                 Local Zones
#                             </title>
# <abstract>Run latency sensitive applications closer to end users</abstract>
# <image src="images/service-icons/Arch_AWS-Local-Zones_32.svg">
# <alt>AWSLocal Zones icon</alt>
#
# </list-card-item>
# <list-card-item href="/batch/?icmpid=docs_homepage_compute" id="batch">
# <title>
#                                 AWS Batch
#                             </title>
# <abstract>Run batch jobs at any scale</abstract>
# <image src="images/service-icons/Arch_AWS-Batch_32.svg">
# <alt>AWS Batch icon</alt>
#
# </list-card-item>
# <list-card-item href="/imagebuilder/?icmpid=docs_homepage_compute" id="IB">
# <title>
#                                 EC2 Image Builder
#                             </title>
# <abstract>Automate lifecycle management of "golden" server images</abstract>
# <image src="images/service-icons/Arch_Amazon-EC2-Image-Builder_32.svg">
# <alt>Amazon EC2 Image Builder icon</alt>
#
# </list-card-item>
# <list-card-item href="/outposts/?icmpid=docs_homepage_compute" id="aws-outposts">
# <title>
#                                 AWS Outposts
#                             </title>
# <abstract>Run AWS infrastructure on-premises</abstract>
# <image src="images/service-icons/Arch-Category_Compute_32.svg">
# <alt>AWS Outposts icon</alt>
#
# </list-card-item>
# <list-card-item href="/pcs/?icmpid=docs_homepage_compute" validate="true">
# <title>
#                                 AWS
#                                 Parallel Computing Service
#                             </title>
# <abstract>Easily run HPC workloads at virtually any scale</abstract>
# <image src="images/service-icons/Arch-Category_Compute_32.svg">
# <alt>AWSParallel Computing Service icon</alt>
#
# </list-card-item>
# <list-card-item href="/parallelcluster/?icmpid=docs_homepage_compute" id="aws-parallelcluster">
# <title>
#                                 AWS ParallelCluster
#                             </title>
# <abstract>Deploy and manage high performance computing clusters in the AWS Cloud</abstract>
# <image src="images/service-icons/Arch_AWS-ParallelCluster_32.svg">
# <alt>AWS ParallelCluster icon</alt>
#
# </list-card-item>
# <list-card-item href="/serverless-application-model/?icmpid=docs_homepage_compute" id="SAM">
# <title>
#                                 AWS SAM
#                             </title>
# <abstract>Build serverless applications on AWS</abstract>
# <image src="images/service-icons/Arch-Category_Compute_32.svg">
# <alt>AWS SAM icon</alt>
#
# </list-card-item>
# <list-card-item href="/serverlessrepo/?icmpid=docs_homepage_compute" id="serverlessrepo">
# <title>
#                                 AWS Serverless Application Repository
#                             </title>
# <abstract>Discover, deploy, and publish serverless applications</abstract>
# <image src="images/service-icons/Arch_AWS-Serverless-Application-Repository_32.svg">
# <alt>AWS Serverless Application Repository icon</alt>
#
# </list-card-item>
# <list-card-item href="/simspaceweaver/?icmpid=docs_homepage_compute" id="simspaceweaver">
# <title>
#                                 AWS SimSpace Weaver
#                             </title>
# <abstract>Build and run large-scale spatial simulations in the AWS Cloud</abstract>
# <image src="images/service-icons/Arch_AWS-SimSpace-Weaver_32.svg">
# <alt>AWS SimSpace Weaver icon</alt>
#
# </list-card-item>
# <list-card-item href="/wavelength/?icmpid=docs_homepage_compute" id="WAVE">
# <title>
#                                 AWS Wavelength
#                             </title>
# <abstract>Deliver ultra-low latency applications for 5G devices</abstract>
# <image src="images/service-icons/Arch_AWS-Wavelength_32.svg">
# <alt>AWS Wavelength icon</alt>
#
# </list-card-item>
# </list-card-items>
# </list-card>
# <list-card id="DocsCategory-computehpc">
# <title>Compute HPC</title>
# <list-card-items>
# <list-card-item href="/res/?icmpid=docs_homepage_compute-hpc">
# <title>
#                                 Research and Engineering Studio on AWS
#                             </title>
# <abstract>Create and manage portals for research collaboration</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Research and Engineering Studio on AWS icon</alt>
#
# </list-card-item>
# </list-card-items>
# </list-card>
# <list-card id="DocsCategory-containers">
# <title>Containers</title>
# <list-card-items>
# <list-card-item href="/decision-guides/latest/containers-on-aws-how-to-choose/choosing-aws-container-service.html?icmpid=docs_homepage_containers">
# <title>Choosing an AWS container service</title>
# <abstract>Choose the right AWS container service for your modern app development</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Decision guide icon</alt>
#
# </list-card-item>
# <list-card-item href="/app2container/?icmpid=docs_homepage_containers" id="a2c">
# <title>
#                                 AWS App2Container
#                             </title>
# <abstract>Containerize and migrate existing applications</abstract>
# <image src="images/service-icons/Arch-Category_Containers_32.svg">
# <alt>AWS App2Container icon</alt>
#
# </list-card-item>
# <list-card-item href="/ecr/?icmpid=docs_homepage_containers" id="ec2containerregistry">
# <title>
#                                 Amazon ECR
#                             </title>
# <abstract>Easily store, manage, and deploy container images</abstract>
# <image src="images/service-icons/Arch_Amazon-Elastic-Container-Registry_32.svg">
# <alt>Amazon ECR icon</alt>
#
# </list-card-item>
# <list-card-item href="/ecs/?icmpid=docs_homepage_containers" id="ec2containerservice">
# <title>
#                                 Amazon ECS
#                             </title>
# <abstract>Highly secure, reliable, and scalable way to run containers</abstract>
# <image src="images/service-icons/Arch_Amazon-Elastic-Container-Service_32.svg">
# <alt>Amazon ECS icon</alt>
#
# </list-card-item>
# <list-card-item href="/eks/?icmpid=docs_homepage_containers" id="EKS">
# <title>
#                                 Amazon EKS
#                             </title>
# <abstract>Run Kubernetes on AWS without operating your own Kubernetes clusters</abstract>
# <image src="images/service-icons/Arch_Amazon-Elastic-Kubernetes-Service_32.svg">
# <alt>Amazon EKS icon</alt>
#
# </list-card-item>
# <list-card-item href="/rosa/?icmpid=docs_homepage_containers" id="rosa">
# <title>
#                                 Red Hat OpenShift Service on AWS
#                             </title>
# <abstract>Managed OpenShift in the cloud</abstract>
# <image src="images/service-icons/Arch_Red-Hat-OpenShift-Service-on-AWS_32.svg">
# <alt>Red Hat OpenShift Service on AWS icon</alt>
#
# </list-card-item>
# </list-card-items>
# </list-card>
# <list-card id="DocsCategory-cryptographypki">
# <title>Cryptography &amp; PKI</title>
# <list-card-items>
# <list-card-item href="/acm/?icmpid=docs_homepage_crypto" id="certificatemanager">
# <title>
#                                 AWS Certificate Manager
#                             </title>
# <abstract>Provision, manage, and deploy SSL/TLS certificates</abstract>
# <image src="images/service-icons/Arch_AWS-Certificate-Manager_32.svg">
# <alt>AWS Certificate Manager icon</alt>
#
# </list-card-item>
# <list-card-item href="/decision-guides/latest/cryptography-on-aws-how-to-choose/guide.html?icmpid=docs_homepage_decision_guides">
# <title>Choosing an AWS cryptography service</title>
# <abstract>Choose the right AWS cryptography service</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Decision guide icon</alt>
#
# </list-card-item>
# <list-card-item href="/cloudhsm/?icmpid=docs_homepage_crypto" id="cloudhsmv2">
# <title>
#                                 AWS CloudHSM
#                             </title>
# <abstract>Hardware-based key storage for regulatory compliance</abstract>
# <image src="images/service-icons/Arch_AWS-CloudHSM_32.svg">
# <alt>AWS CloudHSM icon</alt>
#
# </list-card-item>
# <list-card-item href="/aws-crypto-tools/?icmpid=docs_homepage_crypto">
# <title>
#                                 AWS
#                                 Crypto Tools
#                             </title>
# <abstract>Helping you do cryptography right, even without special expertise</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>AWSCrypto Tools icon</alt>
#
# </list-card-item>
# <list-card-item href="/kms/?icmpid=docs_homepage_crypto" id="kms">
# <title>
#                                 AWS KMS
#                             </title>
# <abstract>Managed creation and control of encryption keys</abstract>
# <image src="images/service-icons/Arch_AWS-Key-Management-Service_32.svg">
# <alt>AWS KMS icon</alt>
#
# </list-card-item>
# <list-card-item href="/privateca/?icmpid=docs_homepage_crypto" id="ACMPrivateCA">
# <title>
#                                 AWS Private Certificate Authority
#                             </title>
# <abstract>Create private certificates to identify resources and protect data</abstract>
# <image src="images/service-icons/Arch_AWS-Private-Certificate-Authority_32.svg">
# <alt>AWS Private Certificate Authority icon</alt>
#
# </list-card-item>
# <list-card-item href="/signer/?icmpid=docs_homepage_crypto" id="signer">
# <title>
#                                 AWS Signer
#                             </title>
# <abstract>Validate AWS Lambda and IoT device code against a digital signature</abstract>
# <image src="images/service-icons/Arch_AWS-Signer_32.svg">
# <alt>AWS Signer icon</alt>
#
# </list-card-item>
# </list-card-items>
# </list-card>
# <list-card id="DocsCategory-customerenablementservices">
# <title>Customer Enablement Services</title>
# <list-card-items>
# <list-card-item href="/aws-iq/?icmpid=docs_homepage_custenable">
# <title>
#                                 AWS
#                                 IQ
#                             </title>
# <abstract>Find AWS Certified third-party experts for on-demand project work</abstract>
# <image src="images/service-icons/Arch_AWS-IQ_32.svg">
# <alt>AWSIQ icon</alt>
#
# </list-card-item>
# <list-card-item href="/aws-support/?icmpid=docs_homepage_custenable">
# <title>AWS Incident Detection and Response</title>
# <abstract>Proactive monitoring and incident management for production workloads</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>AWS Incident Detection and Response icon</alt>
#
# </list-card-item>
# <list-card-item href="/managedservices/?icmpid=docs_homepage_custenable" id="AMS">
# <title>
#                                 AWS Managed Services
#                             </title>
# <abstract>Infrastructure operations management for AWS</abstract>
# <image src="images/service-icons/Arch_AWS-Managed-Services_32.svg">
# <alt>AWS Managed Services icon</alt>
#
# </list-card-item>
# <list-card-item href="https://aws.amazon.com/professional-services/?icmpid=docs_homepage_custenable">
# <title>
#                                 AWS
#                                 Professional Services
#                             </title>
# <abstract>Get help executing your enterprise cloud computing initiatives</abstract>
# <image src="images/service-icons/Arch_AWS-Professional-Services_32.svg">
# <alt>AWSProfessional Services icon</alt>
#
# </list-card-item>
# <list-card-item href="/repostprivate/?icmpid=docs_homepage_console" id="repostspace">
# <title>
#                                 AWS re:Post Private
#                             </title>
# <abstract>Build an organization-specific knowledge resource for your cloud community</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>AWS re:Post Private icon</alt>
#
# </list-card-item>
# <list-card-item href="https://aws.amazon.com/training/?icmpid=docs_homepage_custenable">
# <title>AWS Training and Certification</title>
# <abstract>Explore AWS learning opportunities</abstract>
# <image src="images/service-icons/Arch_AWS-Training-Certification_32.svg">
# <alt>AWS Training and Certification icon</alt>
#
# </list-card-item>
# </list-card-items>
# </list-card>
# <list-card id="DocsCategory-database">
# <title>Database</title>
# <list-card-items>
# <list-card-item href="/decision-guides/latest/databases-on-aws-how-to-choose/databases-on-aws-how-to-choose.html?icmpid=docs_homepage_databases">
# <title>Choosing an AWS database service</title>
# <abstract>Choose the right AWS database service</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Decision guide icon</alt>
#
# </list-card-item>
# <list-card-item href="/rds/?icmpid=docs_homepage_databases" id="aurora">
# <title>
#                                 Amazon Aurora
#                             </title>
# <abstract>High performance managed relational database engine</abstract>
# <image src="images/service-icons/Arch_Amazon-Aurora_32.svg">
# <alt>Amazon Aurora icon</alt>
#
# </list-card-item>
# <list-card-item href="/aurora-dsql/?icmpid=docs_homepage_databases" id="dsql">
# <title>
#                                 Amazon Aurora DSQL
#                             </title>
# <abstract>Fastest serverless distributed SQL database for always available applications</abstract>
# </list-card-item>
# <list-card-item href="/documentdb/?icmpid=docs_homepage_databases" id="amazondocdb">
# <title>
#                                 Amazon DocumentDB (with MongoDB compatibility)
#                             </title>
# <abstract>Fully managed document database</abstract>
# <image src="images/service-icons/Arch_Amazon-DocumentDB_32.svg">
# <alt>Amazon DocumentDB icon</alt>
#
# </list-card-item>
# <list-card-item href="/dynamodb/?icmpid=docs_homepage_databases" id="dynamodb">
# <title>
#                                 Amazon DynamoDB
#                             </title>
# <abstract>Managed NoSQL database</abstract>
# <image src="images/service-icons/Arch_Amazon-DynamoDB_32.svg">
# <alt>Amazon DynamoDB icon</alt>
#
# </list-card-item>
# <list-card-item href="/elasticache/?icmpid=docs_homepage_databases" id="elasticache">
# <title>
#                                 Amazon ElastiCache
#                             </title>
# <abstract>In-memory caching service</abstract>
# <image src="images/service-icons/Arch_Amazon-ElastiCache_32.svg">
# <alt>Amazon ElastiCache icon</alt>
#
# </list-card-item>
# <list-card-item href="/keyspaces/?icmpid=docs_homepage_databases" id="KEY">
# <title>
#                                 Amazon Keyspaces (for Apache Cassandra)
#                             </title>
# <abstract>Managed Cassandra-compatible database</abstract>
# <image src="images/service-icons/Arch_Amazon-Keyspaces_32.svg">
# <alt>Amazon Keyspaces (for Apache Cassandra) icon</alt>
#
# </list-card-item>
# <list-card-item href="/memorydb/?icmpid=docs_homepage_databases" id="memorydb">
# <title>
#                                 Amazon MemoryDB
#                             </title>
# <abstract>Redis-compatible, durable, in-memory database service</abstract>
# <image src="images/service-icons/Arch_Amazon-MemoryDB-for-Redis_32.svg">
# <alt>Amazon MemoryDB icon</alt>
#
# </list-card-item>
# <list-card-item href="/neptune/?icmpid=docs_homepage_databases" id="neptune">
# <title>
#                                 Amazon Neptune
#                             </title>
# <abstract>Fully managed graph database service</abstract>
# <image src="images/service-icons/Arch_Amazon-Neptune_32.svg">
# <alt>Amazon Neptune icon</alt>
#
# </list-card-item>
# <list-card-item href="/odb/?icmpid=docs_homepage_databases" id="odb">
# <title>
#                                 Oracle Database@AWS
#                             </title>
# <abstract>Access Oracle Exadata infrastructure managed by OCI inside AWS data centers</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Oracle Database@AWS icon</alt>
#
# </list-card-item>
# <list-card-item href="/rds/?icmpid=docs_homepage_databases" id="rds">
# <title>
#                                 Amazon Relational Database Service
#                             </title>
# <abstract>Set up, operate, and scale a relational database in the cloud</abstract>
# <image src="images/service-icons/Arch_Amazon-RDS_32.svg">
# <alt>Amazon RDS icon</alt>
#
# </list-card-item>
# <list-card-item href="/timestream/?icmpid=docs_homepage_databases" id="TIME">
# <title>
#                                 Amazon Timestream
#                             </title>
# <abstract>Fully managed time series database</abstract>
# <image src="images/service-icons/Arch_Amazon-Timestream_32.svg">
# <alt>Amazon Timestream icon</alt>
#
# </list-card-item>
# </list-card-items>
# </list-card>
# <list-card id="DocsCategory-decisionguides">
# <title>Decision Guides</title>
# <list-card-items>
# <list-card-item href="/decision-guides/latest/generative-ai-on-aws-how-to-choose/guide.html?icmpid=docs_homepage_decision_guides">
# <title>Choosing a generative AI service</title>
# <abstract>Determine which AWS generative AI services are the best fit for your organization</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Decision guide icon</alt>
#
# </list-card-item>
# <list-card-item href="/decision-guides/latest/bedrock-or-sagemaker/bedrock-or-sagemaker.html?icmpid=docs_homepage_decision_guides">
# <title>Amazon Bedrock or Amazon SageMaker AI?</title>
# <abstract>Determine which service is the best fit for your needs</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Decision guide icon</alt>
#
# </list-card-item>
# <list-card-item href="/decision-guides/latest/cloudtrail-or-cloudwatch/cloudtrail-or-cloudwatch.html?icmpid=docs_homepage_decision_guides">
# <title>AWS CloudTrail or Amazon CloudWatch?</title>
# <abstract>Understand the differences and pick the one that's right for you</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Decision guide icon</alt>
#
# </list-card-item>
# <list-card-item href="/decision-guides/latest/fargate-or-lambda/fargate-or-lambda.html?icmpid=docs_homepage_decision_guides">
# <title>AWS Fargate or AWS Lambda?</title>
# <abstract>Explore which service better meets your needs for a serverless compute service</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Decision guide icon</alt>
#
# </list-card-item>
# <list-card-item href="/decision-guides/latest/lightsail-or-ec2/lightsail-or-ec2.html?icmpid=docs_homepage_decision_guides">
# <title>Amazon Lightsail or Amazon EC2?</title>
# <abstract>Explore which service better meets your needs for a compute web service</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Decision guide icon</alt>
#
# </list-card-item>
# <list-card-item href="/decision-guides/latest/sns-or-sqs-or-eventbridge/sns-or-sqs-or-eventbridge.html?icmpid=docs_homepage_decision_guides">
# <title>Amazon SQS, Amazon SNS, or Amazon EventBridge?</title>
# <abstract>Choose the best service for your needs</abstract>
# ...
#                             </title>
# <abstract>Helps you respond to and receive CIRT assistance for security events</abstract>
# </list-card-item>
# <list-card-item href="/security-lake/?icmpid=docs_homepage_security" id="securitylake">
# <title>
#                                 Amazon Security Lake
#                             </title>
# <abstract>Automatically centralize your security data with a few clicks</abstract>
# <image src="images/service-icons/Arch_Amazon-Security-Lake_32.svg">
# <alt>Amazon Security Lake icon</alt>
#
# </list-card-item>
# <list-card-item href="/shield/?icmpid=docs_homepage_security" id="Shield" validate="true">
# <title>
#                                 AWS Shield
#                             </title>
# <abstract>DDoS protection</abstract>
# <image src="images/service-icons/Arch_AWS-Shield_32.svg">
# <alt>AWS Shield icon</alt>
#
# </list-card-item>
# <list-card-item href="/verifiedpermissions/?icmpid=docs_homepage_security" id="verifiedpermissions">
# <title>
#                                 Amazon Verified Permissions
#                             </title>
# <abstract>Permissions management and authorization for custom applications</abstract>
# <image src="images/service-icons/Arch-Category_Security-Identity-Compliance_32.svg">
# <alt>Amazon Verified Permissions icon</alt>
#
# </list-card-item>
# <list-card-item href="/waf/?icmpid=docs_homepage_security" id="waf">
# <title>
#                                 AWS WAF
#                             </title>
# <abstract>Filter malicious web traffic</abstract>
# <image src="images/service-icons/Arch_AWS-WAF_32.svg">
# <alt>AWS WAF icon</alt>
#
# </list-card-item>
# </list-card-items>
# </list-card>
# <list-card id="DocsCategory-serverless">
# <title>Serverless</title>
# <list-card-items>
# <list-card-item href="/decision-guides/latest/modern-apps-strategy-on-aws-how-to-choose/modern-apps-strategy-on-aws-how-to-choose.html?docs_homepage_serverless">
# <title>Choosing a modern application strategy</title>
# <abstract>Choose a modern application development approach</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Decision guide icon</alt>
#
# </list-card-item>
# <list-card-item href="/serverless/?icmpid=docs_homepage_serverless">
# <title>Serverless</title>
# <abstract>Introduction to core serverless concepts and services in the AWS Cloud</abstract>
# <image src="images/service-icons/Arch_Amazon-API-Gateway_32.svg">
# <alt>Serverless icon</alt>
#
# </list-card-item>
# <list-card-item href="/apigateway/?icmpid=docs_homepage_serverless" id="apigateway">
# <title>
#                                 Amazon API Gateway
#                             </title>
# <abstract>Build, deploy, and manage APIs</abstract>
# <image src="images/service-icons/Arch_Amazon-API-Gateway_32.svg">
# <alt>Amazon API Gateway icon</alt>
#
# </list-card-item>
# <list-card-item href="/appsync/?icmpid=docs_homepage_serverless" id="appsync">
# <title>
#                                 AWS AppSync
#                             </title>
# <abstract>Accelerate app development with fully-managed, scalable GraphQL APIs</abstract>
# <image src="images/service-icons/Arch_AWS-AppSync_32.svg">
# <alt>AWS AppSync icon</alt>
#
# </list-card-item>
# <list-card-item href="/dynamodb/?icmpid=docs_homepage_serverless" id="dynamodb">
# <title>
#                                 Amazon DynamoDB
#                             </title>
# <abstract>Managed NoSQL database</abstract>
# <image src="images/service-icons/Arch_Amazon-DynamoDB_32.svg">
# <alt>Amazon DynamoDB icon</alt>
#
# </list-card-item>
# <list-card-item href="/eventbridge/?icmpid=docs_homepage_serverless" id="eventbridge">
# <title>
#                                 Amazon EventBridge
#                             </title>
# <abstract>Serverless event bus for SaaS apps and AWS services</abstract>
# <image src="images/service-icons/Arch_Amazon-EventBridge_32.svg">
# <alt>Amazon EventBridge icon</alt>
#
# </list-card-item>
# <list-card-item href="/AmazonECS/latest/developerguide/AWS_Fargate.html?icmpid=docs_homepage_serverless" id="fargate">
# <title>
#                                 AWS Fargate
#                             </title>
# <abstract>Serverless compute for containers</abstract>
# <image src="images/service-icons/Arch_AWS-Fargate_32.svg">
# <alt>AWS Fargate icon</alt>
#
# </list-card-item>
# <list-card-item href="/lambda/?icmpid=docs_homepage_serverless" id="lambda">
# <title>
#                                 AWS Lambda
#                             </title>
# <abstract>Run code without thinking about servers</abstract>
# <image src="images/service-icons/Arch_AWS-Lambda_32.svg">
# <alt>AWS Lambda icon</alt>
#
# </list-card-item>
# <list-card-item href="/s3/?icmpid=docs_homepage_serverless" id="S3">
# <title>
#                                 Amazon S3
#                             </title>
# <abstract>Object storage built to retrieve any amount of data from anywhere</abstract>
# <image src="images/service-icons/Arch_Amazon-Simple-Storage-Service_32.svg">
# <alt>Amazon S3 icon</alt>
#
# </list-card-item>
# <list-card-item href="/sns/?icmpid=docs_homepage_serverless" id="sns">
# <title>
#                                 Amazon SNS
#                             </title>
# <abstract>Pub/sub, SMS, email, and mobile push notifications</abstract>
# <image src="images/service-icons/Arch_Amazon-Simple-Notification-Service_32.svg">
# <alt>Amazon SNS icon</alt>
#
# </list-card-item>
# <list-card-item href="/step-functions/?icmpid=docs_homepage_serverless" id="states">
# <title>
#                                 AWS Step Functions
#                             </title>
# <abstract>Coordinate components for distributed applications</abstract>
# <image src="images/service-icons/Arch_AWS-Step-Functions_32.svg">
# <alt>AWS Step Functions icon</alt>
#
# </list-card-item>
# <list-card-item href="/sqs/?icmpid=docs_homepage_serverless" id="sqs">
# <title>
#                                 Amazon SQS
#                             </title>
# <abstract>Managed message queues</abstract>
# <image src="images/service-icons/Arch_Amazon-Simple-Queue-Service_32.svg">
# <alt>Amazon SQS icon</alt>
#
# </list-card-item>
# </list-card-items>
# </list-card>
# <list-card id="DocsCategory-storage">
# <title>Storage</title>
# <list-card-items>
# <list-card-item href="/aws-backup/?icmpid=docs_homepage_storage" id="Cryo">
# <title>
#                                 AWS Backup
#                             </title>
# <abstract>Centralized backup across AWS services</abstract>
# <image src="images/service-icons/Arch_AWS-Backup_32.svg">
# <alt>AWS Backup icon</alt>
#
# </list-card-item>
# <list-card-item href="/decision-guides/latest/storage-on-aws-how-to-choose/choosing-aws-storage-service.html?icmpid=docs_homepage_storage">
# <title>Choosing an AWS storage service</title>
# <abstract>Choose the right AWS storage service</abstract>
# <image src="images/service-icons/Arch-General_Resource.svg">
# <alt>Decision guide icon</alt>
#
# </list-card-item>
# <list-card-item href="/ebs/?icmpid=docs_homepage_storage" id="ebs">
# <title>
#                                 Amazon EBS
#                             </title>
# <abstract>Amazon EC2 block storage volumes</abstract>
# <image src="images/service-icons/Arch_Amazon-Elastic-Block-Store_32.svg">
# <alt>Amazon EBS icon</alt>
#
# </list-card-item>
# <list-card-item href="/drs/?icmpid=docs_homepage_storage" id="drs">
# <title>
#                                 AWS Elastic Disaster Recovery
#                             </title>
# <abstract>Scalable, cost-effective application recovery to AWS</abstract>
# <image src="images/service-icons/Arch_AWS-Elastic-Disaster-Recovery_32.svg">
# <alt>AWS Elastic Disaster Recovery icon</alt>
#
# </list-card-item>
# <list-card-item href="/efs/?icmpid=docs_homepage_storage" id="elasticfilesystem">
# <title>
#                                 Amazon Elastic File System
#                             </title>
# <abstract>Fully managed file system for Amazon EC2</abstract>
# <image src="images/service-icons/Arch_Amazon-EFS_32.svg">
# <alt>Amazon EFS icon</alt>
#
# </list-card-item>
# <list-card-item href="/fsx/?icmpid=docs_homepage_storage" id="FSx">
# <title>
#                                 Amazon FSx
#                             </title>
# <abstract>Launch, run, and scale feature-rich and high-performing file systems</abstract>
# <image src="images/service-icons/Arch_Amazon-FSx_32.svg">
# <alt>Amazon FSx icon</alt>
#
# </list-card-item>
# <list-card-item href="/s3/?icmpid=docs_homepage_storage" id="glacier">
# <title>
#                                 Amazon Glacier
#                             </title>
# <abstract>Low-cost archive storage in the AWS Cloud</abstract>
# <image src="images/service-icons/Arch_Amazon-Simple-Storage-Service-Glacier_32.svg">
# <alt>Amazon Glacier icon</alt>
#
# </list-card-item>
# <list-card-item href="/s3/?icmpid=docs_homepage_storage" id="S3">
# <title>
#                                 Amazon S3
#                             </title>
# <abstract>Object storage built to retrieve any amount of data from anywhere</abstract>
# <image src="images/service-icons/Arch_Amazon-Simple-Storage-Service_32.svg">
# <alt>Amazon S3 icon</alt>
#
# </list-card-item>
# <list-card-item href="/snowball/?icmpid=docs_homepage_storage" id="snowballedge">
# <title>
#                                 AWS Snowball Edge
#                             </title>
# <abstract>Move petabytes of data to and from AWS, or process data at the edge</abstract>
# <image src="images/service-icons/Arch_AWS-Snowball_32.svg">
# <alt>AWS Snowball Edge icon</alt>
#
# </list-card-item>
# <list-card-item href="/storagegateway/?icmpid=docs_homepage_storage" id="storagegateway">
# <title>
#                                 AWS Storage Gateway
#                             </title>
# <abstract>Hybrid storage integration</abstract>
# <image src="images/service-icons/Arch_AWS-Storage-Gateway_32.svg">
# <alt>AWS Storage Gateway icon</alt>
#
# </list-card-item>
# </list-card-items>
# </list-card>
# </cards>
# </section>
# <section id="developer_resources">
# <title>Developer resources</title>
# <subtitle>Find AWS software development kits (SDKs) &amp; toolkits, code examples, and more.</subtitle>
# <cards>
# <simple-card>
# <title>
#                         AWS CLI
#                     </title>
# <abstract>The AWS Command Line Interface (AWS CLI) is a unified tool to
#                         manage your AWS products</abstract>
# <footer>
# <footer-item href="/cli/latest/userguide/cli-chap-welcome.html">AWS CLI User Guide</footer-item>
# <footer-item href="/cli/latest/userguide/getting-started-install.html">Install the latest version of the AWS CLI</footer-item>
# <footer-item href="/cli/latest/userguide/cli-chap-configure.html">Configure the AWS CLI</footer-item>
# </footer>
# </simple-card>
# <list-card id="sdks">
# <title>SDKs &amp; toolkits</title>
# <list-card-items>
# <list-card-item href="/cdk/?icmpid=docs_homepage_sdktoolkits">
# <title>
#                                 AWS CDK
#                             </title>
# <image src="images/sdks/logo-cdk.svg">
# <alt>AWS CDK icon</alt>
#
# </list-card-item>
# <list-card-item href="/sdk-for-cpp/?icmpid=docs_homepage_sdktoolkits">
# <title>C++</title>
# <image src="images/sdks/logo-cpp-new.svg">
# <alt>C++ icon</alt>
#
# </list-card-item>
# <list-card-item href="/sdk-for-go/?icmpid=docs_homepage_sdktoolkits">
# <title>Go</title>
# <image src="images/sdks/logo-go-new.svg">
# <alt>Go icon</alt>
#
# </list-card-item>
# <list-card-item href="/sdk-for-java/?icmpid=docs_homepage_sdktoolkits">
# <title>Java</title>
# <image src="images/sdks/logo-java-new.svg">
# <alt>Java icon</alt>
#
# </list-card-item>
# <list-card-item href="/sdk-for-javascript/?icmpid=docs_homepage_sdktoolkits">
# <title>JavaScript</title>
# <image src="images/sdks/logo-js-new.svg">
# <alt>JavaScript icon</alt>
#
# </list-card-item>
# <list-card-item href="/sdk-for-kotlin/?icmpid=docs_homepage_sdktoolkits">
# <title>Kotlin</title>
# <image src="images/sdks/logo-kotlin.svg">
# <alt>Kotlin icon</alt>
#
# </list-card-item>
# <list-card-item href="/sdk-for-net/?icmpid=docs_homepage_sdktoolkits">
# <title>.NET</title>
# <image src="images/sdks/logo-net-new.svg">
# <alt>.NET icon</alt>
#
# </list-card-item>
# <list-card-item href="/sdk-for-php/?icmpid=docs_homepage_sdktoolkits">
# <title>PHP</title>
# <image src="images/sdks/logo-php-new.svg">
# <alt>PHP icon</alt>
#
# </list-card-item>
# <list-card-item href="/pythonsdk/?icmpid=docs_homepage_sdktoolkits">
# <title>Python</title>
# <image src="images/sdks/logo-python-new.svg">
# <alt>Python icon</alt>
#
# </list-card-item>
# <list-card-item href="/sdk-for-ruby/?icmpid=docs_homepage_sdktoolkits">
# <title>Ruby</title>
# <image src="images/sdks/logo-ruby-new.svg">
# <alt>Ruby icon</alt>
#
# </list-card-item>
# <list-card-item href="/sdk-for-rust/?icmpid=docs_homepage_sdktoolkits">
# <title>Rust</title>
# <image src="images/sdks/logo-rust.svg">
# <alt>Rust icon</alt>
#
# </list-card-item>
# <list-card-item href="/sdk-for-swift/?icmpid=docs_homepage_sdktoolkits">
# <title>Swift</title>
# <image src="images/sdks/logo-swift.svg">
# <alt>Swift icon</alt>
#
# </list-card-item>
# <list-card-item href="/sdk-for-sapabap/?icmpid=docs_homepage_sdktoolkits">
# <title>SAP ABAP</title>
# <image src="images/sdks/logo-sap.svg">
# <alt>SAP ABAP icon</alt>
#
# </list-card-item>
# <list-card-item href="/corretto/?icmpid=docs_homepage_sdktoolkits">
# <title>
#                                 Amazon Corretto
#                             </title>
# <image src="images/sdks/logo-sap.svg">
# <alt>Amazon Corretto icon</alt>
#
# </list-card-item>
# <list-card-item href="/vsts/?icmpid=docs_homepage_sdktoolkits">
# <title>Azure DevOps</title>
# <image src="images/sdks/logo-sap.svg">
# <alt>Azure DevOps icon</alt>
#
# </list-card-item>
# <list-card-item href="/toolkit-for-jetbrains/?icmpid=docs_homepage_sdktoolkits">
# <title>JetBrains</title>
# <image src="images/sdks/logo-sap.svg">
# <alt>JetBrains icon</alt>
#
# </list-card-item>
# <list-card-item href="/powershell/?icmpid=docs_homepage_sdktoolkits">
# <title>PowerShell</title>
# <image src="images/sdks/logo-sap.svg">
# <alt>PowerShell icon</alt>
#
# </list-card-item>
# <list-card-item href="/amazonq/latest/qdeveloper-ug/what-is.html?icmpid=docs_homepage_sdktoolkits">
# <title>
#                                 Amazon Q Developer
#                             </title>
# <image src="images/sdks/logo-sap.svg">
# <alt>Amazon Q Developer icon</alt>
#
# </list-card-item>
# <list-card-item href="/aws-toolkit-visual-studio/?icmpid=docs_homepage_sdktoolkits">
# <title>Visual Studio</title>
# <image src="images/sdks/logo-sap.svg">
# <alt>Visual Studio icon</alt>
#
# </list-card-item>
# <list-card-item href="/toolkit-for-vscode/?icmpid=docs_homepage_sdktoolkits">
# <title>Visual Studio Code</title>
# <image src="images/sdks/logo-sap.svg">
# <alt>Visual Studio Code icon</alt>
#
# </list-card-item>
# </list-card-items>
# <more-info href="https://builder.aws.com/tools/">View all SDKs &amp; toolkits</more-info>
# </list-card>
# <image-card>
# <title href="/code-library/latest/ug/what-is-code-library.html">Code Example Library</title>
# <abstract>Find code examples that show you how to use AWS SDKs with AWS</abstract>
# <footer/>
# <image src="images/cards/code-example-library-light.svg" src-dark="images/cards/code-example-library-dark.svg">
# <alt>Code Example Library icon</alt>
#
# </image-card>
# <image-card>
# <title href="https://builder.aws.com/">AWS Builder Center</title>
# <abstract>Learn, build, and connect with builders in the AWS community</abstract>
# <footer/>
# <image src="images/cards/aws-dev-center-light.svg" src-dark="images/cards/aws-dev-center-dark.svg">
# <alt>AWS Builder Center icon</alt>
#
# </image-card>
# <image-card>
# <title href="https://aws.amazon.com/blogs/developer/">AWS Developer Tools Blog</title>
# <abstract>Find blog posts for developers written by AWS experts</abstract>
# <footer/>
# <image src="images/cards/aws-dev-blog-light.svg" src-dark="images/cards/aws-dev-blog-dark.svg">
# <alt>AWS Developer Tools Blog icon</alt>
#
# </image-card>
# <image-card>
# <title href="https://repost.aws/">
#                         AWS re:Post
#                     </title>
# <abstract>Find expert-reviewed answers, Knowledge Center articles and videos, and curated knowledge paths</abstract>
# <footer/>
# <image src="images/cards/aws-repost-light.svg" src-dark="images/cards/aws-repost-dark.svg">
# <alt>
#                             AWS re:Post
#                         </alt>
#
# </image-card>
# </cards>
# </section>
# </sections>
# </main-landing-page>

# %%
service_links = []

# %%
containers = soup.find_all("list-card-items")
len(containers), containers[0]  # shows the first container so you can inspect it
# Out:
# (33,
#  <list-card-items>
#  <list-card-item href="/ec2/?icmpid=docs_homepage_featuredsvcs" id="ec2">
#  <title>
#                                  Amazon EC2
#                              </title>
#  <abstract>Create and run virtual servers in the cloud</abstract>
#  <image src="images/service-icons/Arch_Amazon-EC2_32.svg">
#  <alt>Amazon EC2 icon</alt>
#
#  </list-card-item>
#  <list-card-item href="/s3/?icmpid=docs_homepage_featuredsvcs" id="S3">
#  <title>
#                                  Amazon S3
#                              </title>
#  <abstract>Object storage built to retrieve any amount of data from anywhere</abstract>
#  <image src="images/service-icons/Arch_Amazon-Simple-Storage-Service_32.svg">
#  <alt>Amazon S3 icon</alt>
#
#  </list-card-item>
#  <list-card-item href="/dynamodb/?icmpid=docs_homepage_featuredsvcs" id="dynamodb">
#  <title>
#                                  Amazon DynamoDB
#                              </title>
#  <abstract>Managed NoSQL database service</abstract>
#  <image src="images/service-icons/Arch_Amazon-DynamoDB_32.svg">
#  <alt>Amazon DynamoDB icon</alt>
#
#  </list-card-item>
#  <list-card-item href="/rds/?icmpid=docs_homepage_featuredsvcs" id="rds">
#  <title>
#                                  Amazon Relational Database Service
#                              </title>
#  <abstract>Set up, operate, and scale a relational database in the cloud</abstract>
#  <image src="images/service-icons/Arch_Amazon-RDS_32.svg">
#  <alt>Amazon RDS icon</alt>
#
#  </list-card-item>
#  <list-card-item href="/lambda/?icmpid=docs_homepage_featuredsvcs" id="lambda">
#  <title>
#                                  AWS Lambda
#                              </title>
#  <abstract>Run code without thinking about servers</abstract>
#  <image src="images/service-icons/Arch_AWS-Lambda_32.svg">
#  <alt>AWS Lambda icon</alt>
#
#  </list-card-item>
#  <list-card-item href="/vpc/?icmpid=docs_homepage_featuredsvcs" id="VPC">
#  <title>
#                                  Amazon VPC
#                              </title>
#  <abstract>Isolated cloud resources</abstract>
#  <image src="images/service-icons/Arch_Amazon-Virtual-Private-Cloud_32.svg">
#  <alt>Amazon VPC icon</alt>
#
#  </list-card-item>
#  <list-card-item href="/next-generation-sagemaker/latest/userguide?icmpid=docs_homepage_featuredsvcs" id="SageMakerPlain">
#  <title>
#                                  Amazon SageMaker
#                              </title>
#  <abstract>The center for all data, analytics, and AI</abstract>
#  <image src="images/service-icons/Arch_Amazon-SageMaker_32.svg">
#  <alt>Amazon SageMaker icon</alt>
#
#  </list-card-item>
#  <list-card-item href="/decision-guides/latest/generative-ai-on-aws-how-to-choose/guide.html?icmpid=docs_homepage_featuredsvcs">
#  <title>Choosing a generative AI service</title>
#  <abstract>Determine which AWS generative AI services are the best fit for your organization</abstract>
#  <image src="images/service-icons/Arch-General_Resource.svg">
#  <alt>Decision guide icon</alt>
#
#  </list-card-item>
#  <list-card-item href="/decision-guides/latest/bedrock-or-sagemaker/bedrock-or-sagemaker.html?icmpid=docs_homepage_featuredsvcs">
#  <title>Amazon Bedrock or Amazon SageMaker AI?</title>
#  <abstract>Determine which service is the best fit for your needs</abstract>
#  <image src="images/service-icons/Arch-General_Resource.svg">
#  <alt>Decision guide icon</alt>
#
#  </list-card-item>
#  </list-card-items>)

# %%
cards = soup.find_all("list-card-item")   # <- directly find the child elements
len(cards)
# Out:
# 392

# %%
cards[0].get("href")
# Out:
# '/ec2/?icmpid=docs_homepage_featuredsvcs'

# %%
from urllib.parse import urljoin

service_entries = []
for card in cards:
    href = card.get("href")  # href is usually something like "/ec2/?icmpid=..."
    title_tag = card.find("title")
    title = title_tag.get_text(strip=True) if title_tag else None

    if not href:
        # sometimes href is missing (rare). skip those.
        continue

    # remove query params (we only need the path)
    href_path = href.split("?")[0]

    # normalize to absolute URL
    full_url = urljoin(BASE_URL, href_path)

    service_entries.append({"title": title, "href_raw": href, "href_path": href_path, "url": full_url})

# quick preview
service_entries[:10]
# Out:
# [{'title': 'Amazon EC2',
#   'href_raw': '/ec2/?icmpid=docs_homepage_featuredsvcs',
#   'href_path': '/ec2/',
#   'url': 'https://docs.aws.amazon.com/ec2/'},
#  {'title': 'Amazon S3',
#   'href_raw': '/s3/?icmpid=docs_homepage_featuredsvcs',
#   'href_path': '/s3/',
#   'url': 'https://docs.aws.amazon.com/s3/'},
#  {'title': 'Amazon DynamoDB',
#   'href_raw': '/dynamodb/?icmpid=docs_homepage_featuredsvcs',
#   'href_path': '/dynamodb/',
#   'url': 'https://docs.aws.amazon.com/dynamodb/'},
#  {'title': 'Amazon Relational Database Service',
#   'href_raw': '/rds/?icmpid=docs_homepage_featuredsvcs',
#   'href_path': '/rds/',
#   'url': 'https://docs.aws.amazon.com/rds/'},
#  {'title': 'AWS Lambda',
#   'href_raw': '/lambda/?icmpid=docs_homepage_featuredsvcs',
#   'href_path': '/lambda/',
#   'url': 'https://docs.aws.amazon.com/lambda/'},
#  {'title': 'Amazon VPC',
#   'href_raw': '/vpc/?icmpid=docs_homepage_featuredsvcs',
#   'href_path': '/vpc/',
#   'url': 'https://docs.aws.amazon.com/vpc/'},
#  {'title': 'Amazon SageMaker',
#   'href_raw': '/next-generation-sagemaker/latest/userguide?icmpid=docs_homepage_featuredsvcs',
#   'href_path': '/next-generation-sagemaker/latest/userguide',
#   'url': 'https://docs.aws.amazon.com/next-generation-sagemaker/latest/userguide'},
#  {'title': 'Choosing a generative AI service',
#   'href_raw': '/decision-guides/latest/generative-ai-on-aws-how-to-choose/guide.html?icmpid=docs_homepage_featuredsvcs',
#   'href_path': '/decision-guides/latest/generative-ai-on-aws-how-to-choose/guide.html',
#   'url': 'https://docs.aws.amazon.com/decision-guides/latest/generative-ai-on-aws-how-to-choose/guide.html'},
#  {'title': 'Amazon Bedrock or Amazon SageMaker AI?',
#   'href_raw': '/decision-guides/latest/bedrock-or-sagemaker/bedrock-or-sagemaker.html?icmpid=docs_homepage_featuredsvcs',
#   'href_path': '/decision-guides/latest/bedrock-or-sagemaker/bedrock-or-sagemaker.html',
#   'url': 'https://docs.aws.amazon.com/decision-guides/latest/bedrock-or-sagemaker/bedrock-or-sagemaker.html'},
#  {'title': 'Choosing an AWS analytics service',
#   'href_raw': '/decision-guides/latest/analytics-on-aws-how-to-choose/analytics-on-aws-how-to-choose.html?icmpid=docs_homepage_analytics',
#   'href_path': '/decision-guides/latest/analytics-on-aws-how-to-choose/analytics-on-aws-how-to-choose.html',
#   'url': 'https://docs.aws.amazon.com/decision-guides/latest/analytics-on-aws-how-to-choose/analytics-on-aws-how-to-choose.html'}]

# %%
import pandas as pd
df = pd.DataFrame(service_entries)
df
# Out:
#                                   title  \
# 0                            Amazon EC2
# 1                             Amazon S3
# 2                       Amazon DynamoDB
# 3    Amazon Relational Database Service
# 4                            AWS Lambda
# ..                                  ...
# 387                           JetBrains
# 388                          PowerShell
# 389                  Amazon Q Developer
# 390                       Visual Studio
# 391                  Visual Studio Code
#
#                                               href_raw  \
# 0              /ec2/?icmpid=docs_homepage_featuredsvcs
# 1               /s3/?icmpid=docs_homepage_featuredsvcs
# 2         /dynamodb/?icmpid=docs_homepage_featuredsvcs
# 3              /rds/?icmpid=docs_homepage_featuredsvcs
# 4           /lambda/?icmpid=docs_homepage_featuredsvcs
# ..                                                 ...
# 387  /toolkit-for-jetbrains/?icmpid=docs_homepage_s...
# 388      /powershell/?icmpid=docs_homepage_sdktoolkits
# 389  /amazonq/latest/qdeveloper-ug/what-is.html?icm...
# 390  /aws-toolkit-visual-studio/?icmpid=docs_homepa...
# 391  /toolkit-for-vscode/?icmpid=docs_homepage_sdkt...
#
#                                       href_path  \
# 0                                         /ec2/
# 1                                          /s3/
# 2                                    /dynamodb/
# 3                                         /rds/
# 4                                      /lambda/
# ..                                          ...
# 387                     /toolkit-for-jetbrains/
# 388                                /powershell/
# 389  /amazonq/latest/qdeveloper-ug/what-is.html
# 390                 /aws-toolkit-visual-studio/
# 391                        /toolkit-for-vscode/
#
#                                                    url
# 0                     https://docs.aws.amazon.com/ec2/
# 1                      https://docs.aws.amazon.com/s3/
# 2                https://docs.aws.amazon.com/dynamodb/
# 3                     https://docs.aws.amazon.com/rds/
# 4                  https://docs.aws.amazon.com/lambda/
# ..                                                 ...
# 387  https://docs.aws.amazon.com/toolkit-for-jetbra...
# 388            https://docs.aws.amazon.com/powershell/
# 389  https://docs.aws.amazon.com/amazonq/latest/qde...
# 390  https://docs.aws.amazon.com/aws-toolkit-visual...
# 391    https://docs.aws.amazon.com/toolkit-for-vscode/
#
# [392 rows x 4 columns]

# %%
CORE_SERVICES = {
    "lambda", "ec2", "s3", "iam", "rds", "dynamodb", "glue", "athena",
    "emr", "redshift", "sns", "sqs", "cloudformation", "cloudwatch",
    "kinesis", "ecs", "eks", "api-gateway", "sagemaker", "vpc",
    "route53", "cloudtrail", "kms", "ssm", "secrets-manager", "opensearch",
    "elasticsearch", "lakeformation", "batch", "elasticbeanstalk",
    "transfer", "backup", "cloudfront", "appsync", "step-functions"
}

def path_contains_core(path):
    # split path and check first segment(s)
    parts = [p for p in urlsplit(path).path.split("/") if p]
    if not parts:
        return False
    first = parts[0].lower()
    # some services have multi-word names in path (e.g., next-generation-sagemaker -> sagemaker)
    return any(first == core or core in first for core in CORE_SERVICES)

filtered = [r for r in service_entries if path_contains_core(r["href_path"])]
len(filtered), filtered[:8]
# Out:
# (50,
#  [{'title': 'Amazon EC2',
#    'href_raw': '/ec2/?icmpid=docs_homepage_featuredsvcs',
#    'href_path': '/ec2/',
#    'url': 'https://docs.aws.amazon.com/ec2/'},
#   {'title': 'Amazon S3',
#    'href_raw': '/s3/?icmpid=docs_homepage_featuredsvcs',
#    'href_path': '/s3/',
#    'url': 'https://docs.aws.amazon.com/s3/'},
#   {'title': 'Amazon DynamoDB',
#    'href_raw': '/dynamodb/?icmpid=docs_homepage_featuredsvcs',
#    'href_path': '/dynamodb/',
#    'url': 'https://docs.aws.amazon.com/dynamodb/'},
#   {'title': 'Amazon Relational Database Service',
#    'href_raw': '/rds/?icmpid=docs_homepage_featuredsvcs',
#    'href_path': '/rds/',
#    'url': 'https://docs.aws.amazon.com/rds/'},
#   {'title': 'AWS Lambda',
#    'href_raw': '/lambda/?icmpid=docs_homepage_featuredsvcs',
#    'href_path': '/lambda/',
#    'url': 'https://docs.aws.amazon.com/lambda/'},
#   {'title': 'Amazon VPC',
#    'href_raw': '/vpc/?icmpid=docs_homepage_featuredsvcs',
#    'href_path': '/vpc/',
#    'url': 'https://docs.aws.amazon.com/vpc/'},
#   {'title': 'Amazon SageMaker',
#    'href_raw': '/next-generation-sagemaker/latest/userguide?icmpid=docs_homepage_featuredsvcs',
#    'href_path': '/next-generation-sagemaker/latest/userguide',
#    'url': 'https://docs.aws.amazon.com/next-generation-sagemaker/latest/userguide'},
#   {'title': 'Amazon SageMaker',
#    'href_raw': '/next-generation-sagemaker/latest/userguide?icmpid=docs_homepage_analytics',
#    'href_path': '/next-generation-sagemaker/latest/userguide',
#    'url': 'https://docs.aws.amazon.com/next-generation-sagemaker/latest/userguide'}])

# %%
services = soup.find_all("list-card-items")

# %%
import requests
from urllib.parse import urljoin, urlsplit

def find_pdf_url(service_url):
    parts = urlsplit(service_url)
    base = f"{parts.scheme}://{parts.netloc}{parts.path}"
    if not base.endswith("/"):
        base += "/"
    meta_url = urljoin(base, "meta-inf/guide-info.json")
    try:
        r = requests.get(meta_url, timeout=10)
        if r.status_code == 200:
            data = r.json()
            if "pdf" in data and data["pdf"]:
                return urljoin(base, data["pdf"])
    except Exception:
        return None
    return None

results = []
for entry in filtered:
    pdf = find_pdf_url(entry["url"])
    results.append({"title": entry["title"], "service_url": entry["url"], "pdf_url": pdf})

# show found pdfs
import pandas as pd
pd.DataFrame(results).dropna(subset=["pdf_url"])
# Out:
#               title                                        service_url  \
# 6  Amazon SageMaker  https://docs.aws.amazon.com/next-generation-sa...
# 7  Amazon SageMaker  https://docs.aws.amazon.com/next-generation-sa...
#
#                                              pdf_url
# 6  https://docs.aws.amazon.com/pdfs/next-generati...
# 7  https://docs.aws.amazon.com/pdfs/next-generati...

# %%
import requests
from urllib.parse import urljoin, urlsplit

def find_pdf_url(service_url):
    """
    Try multiple known subpaths (dg, userguide, developerguide, APIReference)
    to find a valid meta-inf/guide-info.json and return the PDF URL.
    """
    parts = urlsplit(service_url)
    base = f"{parts.scheme}://{parts.netloc}{parts.path}"
    if not base.endswith("/"):
        base += "/"

    # Common AWS documentation folder structures
    candidate_subpaths = [
        "",  # direct root (some like SageMaker)
        "latest/dg/",
        "latest/userguide/",
        "latest/developerguide/",
        "latest/APIReference/",
    ]

    for subpath in candidate_subpaths:
        meta_url = urljoin(base, f"{subpath}meta-inf/guide-info.json")
        try:
            r = requests.get(meta_url, timeout=10)
            if r.status_code == 200:
                data = r.json()
                if "pdf" in data and data["pdf"]:
                    pdf_url = urljoin(urljoin(base, subpath), data["pdf"])
                    return pdf_url
        except Exception:
            continue
    return None

# %%
results = []
for entry in filtered:
    pdf = find_pdf_url(entry["url"])
    results.append({
        "title": entry["title"],
        "service_url": entry["url"],
        "pdf_url": pdf
    })

import pandas as pd
df_pdfs = pd.DataFrame(results).dropna(subset=["pdf_url"])
df_pdfs
# Out:
#                                                 title  \
# 4                                          AWS Lambda
# 5                                          Amazon VPC
# 6                                    Amazon SageMaker
# 7                                    Amazon SageMaker
# 8                                       Amazon Athena
# 9                                          Amazon EMR
# 10                                           AWS Glue
# 11                                     Amazon Kinesis
# 12                          Amazon OpenSearch Service
# 13                                    Amazon Redshift
# 14                                         Amazon SNS
# 16                                 AWS Step Functions
# 18                                         AWS Lambda
# 19                                          AWS Batch
# 21                                         Amazon EKS
# 22                                            AWS KMS
# 26                                        AWS AppSync
# 28                                Amazon SageMaker AI
# 31                                  Amazon CloudWatch
# 32  AWS\n                                Data Tran...
# 33                                AWS Transfer Family
# 34                                  Amazon CloudFront
# 36                                         Amazon VPC
# 37                                 Amazon VPC Lattice
# 39                                        AWS AppSync
# 42                                         AWS Lambda
# 44                                         Amazon SNS
# 45                                 AWS Step Functions
#
#                                           service_url  \
# 4                 https://docs.aws.amazon.com/lambda/
# 5                    https://docs.aws.amazon.com/vpc/
# 6   https://docs.aws.amazon.com/next-generation-sa...
# 7   https://docs.aws.amazon.com/next-generation-sa...
# 8                 https://docs.aws.amazon.com/athena/
# 9                    https://docs.aws.amazon.com/emr/
# 10                  https://docs.aws.amazon.com/glue/
# 11               https://docs.aws.amazon.com/kinesis/
# 12    https://docs.aws.amazon.com/opensearch-service/
# 13              https://docs.aws.amazon.com/redshift/
# 14                   https://docs.aws.amazon.com/sns/
# 16        https://docs.aws.amazon.com/step-functions/
# 18                https://docs.aws.amazon.com/lambda/
# 19                 https://docs.aws.amazon.com/batch/
# 21                   https://docs.aws.amazon.com/eks/
# 22                   https://docs.aws.amazon.com/kms/
# 26               https://docs.aws.amazon.com/appsync/
# 28             https://docs.aws.amazon.com/sagemaker/
# 31            https://docs.aws.amazon.com/cloudwatch/
# 32  https://docs.aws.amazon.com/datatransferterminal/
# 33              https://docs.aws.amazon.com/transfer/
# 34            https://docs.aws.amazon.com/cloudfront/
# 36                   https://docs.aws.amazon.com/vpc/
# 37           https://docs.aws.amazon.com/vpc-lattice/
# 39               https://docs.aws.amazon.com/appsync/
# 42                https://docs.aws.amazon.com/lambda/
# 44                   https://docs.aws.amazon.com/sns/
# 45        https://docs.aws.amazon.com/step-functions/
#
#                                               pdf_url
# 4   https://docs.aws.amazon.com/pdfs/lambda/latest...
# 5   https://docs.aws.amazon.com/pdfs/vpc/latest/us...
# 6   https://docs.aws.amazon.com/pdfs/next-generati...
# 7   https://docs.aws.amazon.com/pdfs/next-generati...
# 8   https://docs.aws.amazon.com/pdfs/athena/latest...
# 9   https://docs.aws.amazon.com/pdfs/emr/latest/AP...
# 10  https://docs.aws.amazon.com/pdfs/glue/latest/d...
# 11  https://docs.aws.amazon.com/pdfs/kinesis/lates...
# 12  https://docs.aws.amazon.com/pdfs/opensearch-se...
# 13  https://docs.aws.amazon.com/pdfs/redshift/late...
# 14  https://docs.aws.amazon.com/pdfs/sns/latest/dg...
# 16  https://docs.aws.amazon.com/pdfs/step-function...
# 18  https://docs.aws.amazon.com/pdfs/lambda/latest...
# 19  https://docs.aws.amazon.com/pdfs/batch/latest/...
# 21  https://docs.aws.amazon.com/pdfs/eks/latest/us...
# 22  https://docs.aws.amazon.com/pdfs/kms/latest/de...
# 26  https://docs.aws.amazon.com/pdfs/appsync/lates...
# 28  https://docs.aws.amazon.com/pdfs/sagemaker/lat...
# 31  https://docs.aws.amazon.com/pdfs/cloudwatch/la...
# 32  https://docs.aws.amazon.com/pdfs/datatransfert...
# 33  https://docs.aws.amazon.com/pdfs/transfer/late...
# 34  https://docs.aws.amazon.com/pdfs/cloudfront/la...
# 36  https://docs.aws.amazon.com/pdfs/vpc/latest/us...
# 37  https://docs.aws.amazon.com/pdfs/vpc-lattice/l...
# 39  https://docs.aws.amazon.com/pdfs/appsync/lates...
# 42  https://docs.aws.amazon.com/pdfs/lambda/latest...
# 44  https://docs.aws.amazon.com/pdfs/sns/latest/dg...
# 45  https://docs.aws.amazon.com/pdfs/step-function...

# %%
df_pdfs.iloc[0,2]
# Out:
# 'https://docs.aws.amazon.com/pdfs/lambda/latest/dg/lambda-dg.pdf'

# %%
service_links = []

for item in services:
    href = item.get("href")
    title_tag = item.find("title")
    title = title_tag.get_text(strip=True) if title_tag else None
    if not href or not title:
        continue
    
    # Normalize
    href = href.split("?")[0]  # remove query params like ?icmpid=...
    full_url = urljoin(BASE_URL, href)
    
    service_links.append({
        "title": title,
        "url": full_url
    })

len(service_links)
# Out:
# 0

# %%
services[0].get("href")

# %%
for service in soup.find_all("list-card-items"):
    print(service.get("href"))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
service_links
# Out:
# []

# %%
service_links
# Out:
# []

# %%
def get_service_links():
    """Parse AWS main landing XML and return service doc root URLs for selected services."""
    xml = fetch(LANDING_XML)
    soup = BeautifulSoup(xml, "xml")
    service_links = []
    for service in soup.find_all("service"):
        href = service.get("href")
        if not href:
            continue
        parts = href.strip("/").split("/")
        if not parts:
            continue
        name = parts[0].lower()
        if name in CORE_SERVICES:
            service_links.append(urljoin(BASE_URL, href))
    return service_links


def find_pdf_url(service_url):
    """Given a service doc root, return the PDF URL from guide-info.json."""
    parts = urlsplit(service_url)
    base = f"{parts.scheme}://{parts.netloc}{parts.path}"
    if not base.endswith("/"):
        base += "/"
    meta_url = urljoin(base, "meta-inf/guide-info.json")
    try:
        r = requests.get(meta_url, timeout=10)
        if r.status_code == 200:
            data = r.json()
            if "pdf" in data:
                return urljoin(base, data["pdf"])
    except Exception:
        pass
    return None
